# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1)Write a Python program to import a CSV dataset using Pandas and display the first 5 and last 5 records.**

# %%
import pandas as pd

# %%
df = pd.read_csv("Students.csv")

# %%
print(df.head())
# Out:
#    Roll No       Name Department  Marks  Attendance
# 0      101  Divyanhu      BSc IT     85          86
# 1      102    Predaap     BSc CS     55          91
# 2      103      Rahul     BSc IT     68          82
# 3      104   Abhishek     BSc CS     76          78
# 4      105      Sahil     BSc IT     65          70

# %%
print(df.tail())
# Out:
#    Roll No       Name Department  Marks  Attendance
# 0      101  Divyanhu      BSc IT     85          86
# 1      102    Predaap     BSc CS     55          91
# 2      103      Rahul     BSc IT     68          82
# 3      104   Abhishek     BSc CS     76          78
# 4      105      Sahil     BSc IT     65          70

# %% [markdown]
# **2)Write a Python program to analyze the dataset by displaying the number of rows and columns, column names, data types, and basic statistical information.**

# %%
print(df.shape)
# Out:
# (5, 5)

# %%
print(df.columns)
# Out:
# Index(['Roll No', 'Name', 'Department', 'Marks', 'Attendance'], dtype='object')

# %%
print(df.dtypes)
# Out:
# Roll No        int64
# Name          object
# Department    object
# Marks          int64
# Attendance     int64
# dtype: object

# %% [markdown]
# **3)Write a Python program to filter records from the dataset using conditions. For example, display students having marks greater than 60 or employees having salary greater than 40,000.**

# %%
result = df[df["Attendance"]>=80]
print(result)
# Out:
#    Roll No       Name Department  Marks  Attendance
# 0      101  Divyanhu      BSc IT     85          86
# 1      102    Predaap     BSc CS     55          91
# 2      103      Rahul     BSc IT     68          82

# %% [markdown]
# **4)Write a Python program to sort the dataset based on a selected column and display the top 5 records. For example, sort students by marks or products by price.**

# %%
result = df.sort_values("Marks")
print(result)
# Out:
#    Roll No       Name Department  Marks  Attendance
# 1      102    Predaap     BSc CS     55          91
# 4      105      Sahil     BSc IT     65          70
# 2      103      Rahul     BSc IT     68          82
# 3      104   Abhishek     BSc CS     76          78
# 0      101  Divyanhu      BSc IT     85          86

# %% [markdown]
# **5)Write a Python program to perform data analysis on the dataset by finding the maximum, minimum, average, and total values of a numerical column.**

# %%
print("Maximum Marks ",df["Marks"].max())
print("Minimum Marks ",df["Marks"].min())
print("Average ",df["Marks"].mean())
print("Total Marks ",df["Marks"].sum())
# Out:
# Maximum Marks  85
# Minimum Marks  55
# Average  69.8
# Total Marks  349
